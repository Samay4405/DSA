# %%
# Decimal to Binary

bin(5)[2:]
# Out:
# '101'

# %%
# Convert Binary to Decimal

binary_5 = '101'

int(binary_5, 2)
# Out:
# 5

# %%
# Bitwise AND

5 & 7
# Out:
# 5

# %%
# Bitwise OR

5 | 7
# Out:
# 7

# %%
# Bitwise XOR

5 ^ 7
# Out:
# 2

# %%
# Bitwise NOT

~5
# Out:
# -6

# %%
# Left Shift

5 << 2
# Out:
# 20

# %%
# Arithmetic (Signed) Right Shift

5 >> 1
# Out:
# 2

# %%
# Hexadecimal (Base 16)

# 0 0
# 1 1
# 2 2
# ...
# 9 9
# 10 a 
# 11 b
# 12 c    
# 13 d
# 14 e
# 15 f

hex(890)

3 * 16**2 + 7 * 16**1 + (10) * 16**0
# Out:
# 890
